# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# 設定資料夾路徑
base_dir = "/content/drive/MyDrive/yolo_dog_breeds/dataset"
image_dir = os.path.join(base_dir, "images")
label_dir = os.path.join(base_dir, "labels")

# 確保目標資料夾存在
os.makedirs(os.path.join(base_dir, "images/train"), exist_ok=True)
os.makedirs(os.path.join(base_dir, "images/val"), exist_ok=True)
os.makedirs(os.path.join(base_dir, "labels/train"), exist_ok=True)
os.makedirs(os.path.join(base_dir, "labels/val"), exist_ok=True)

# 取得所有圖片檔案名稱（假設圖片副檔名是 .jpg）
image_files = [f for f in os.listdir(image_dir) if f.endswith(".jpg")]

# 移除副檔名後的基礎名稱
base_names = [os.path.splitext(f)[0] for f in image_files]

# 分割成 train 與 val
train_names, val_names = train_test_split(base_names, test_size=0.2, random_state=42)

# 移動檔案
def move_files(file_names, source_dir, target_dir, extension):
    for name in file_names:
        src = os.path.join(source_dir, f"{name}{extension}")
        dst = os.path.join(target_dir, f"{name}{extension}")
        if os.path.exists(src):
            shutil.move(src, dst)

# 移動圖片和標註檔案
move_files(train_names, image_dir, os.path.join(base_dir, "images/train"), ".jpg")
move_files(val_names, image_dir, os.path.join(base_dir, "images/val"), ".jpg")
move_files(train_names, label_dir, os.path.join(base_dir, "labels/train"), ".txt")
move_files(val_names, label_dir, os.path.join(base_dir, "labels/val"), ".txt")

print(f"完成！訓練集保留 {len(train_names)} 筆，驗證集分割出 {len(val_names)} 筆。")

# %%
import os

# 設定資料夾路徑
base_dir = "/content/drive/MyDrive/yolo_dog_breeds/dataset"
train_images_dir = os.path.join(base_dir, "images/train")
val_images_dir = os.path.join(base_dir, "images/val")
train_labels_dir = os.path.join(base_dir, "labels/train")
val_labels_dir = os.path.join(base_dir, "labels/val")

# 計算每個資料夾的檔案數量
def count_files(directory):
    if os.path.exists(directory):
        return len([f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))])
    return 0

# 計算檔案數量
num_train_images = count_files(train_images_dir)
num_val_images = count_files(val_images_dir)
num_train_labels = count_files(train_labels_dir)
num_val_labels = count_files(val_labels_dir)

# 印出結果
print(f"訓練集圖片數量: {num_train_images}")
print(f"驗證集圖片數量: {num_val_images}")
print(f"訓練集標註數量: {num_train_labels}")
print(f"驗證集標註數量: {num_val_labels}")
# Out:
# 訓練集圖片數量: 7732
# 驗證集圖片數量: 1933
# 訓練集標註數量: 7732
# 驗證集標註數量: 1933

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.55-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.8.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.13-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.12.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.55-py3-none-any.whl (904 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 904.3/904.3 kB 15.4 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.13-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.55 ultralytics-thop-2.0.13

# %%
from ultralytics import YOLO
print(YOLO('yolov8n.pt'))  # 測試是否安裝成功
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 18.1MB/s]
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (4): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (6): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (8): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (9): SPPF(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (10): Upsample(scale_factor=2.0, mode='nearest')
#       (11): Concat()
#       (12): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (13): Upsample(scale_factor=2.0, mode='nearest')
#       (14): Concat()
#       (15): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (16): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (17): Concat()
#       (18): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (19): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (20): Concat()
#       (21): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (22): Detect(
#         (cv2): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (cv3): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (dfl): DFL(
#           (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#     )
#   )
# )

# %%
# 指定儲存路徑
output_dir = "/content/drive/MyDrive/yolo_dog_breeds/dataset"
os.makedirs(output_dir, exist_ok=True)  # 確保資料夾存在
yaml_path = os.path.join(output_dir, "data.yaml")

# YAML 文件內容
yaml_content = """
train: /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train
val: /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val

nc: 19  # 狗品種數量
names: [affenpinscher dog', 'afghan hound dog', 'basenji dog', 'basset hound dog', 'cairn terrier dog',
 'chihuahua dog', dandie dinmont terrier dog', 'deerhound dog', 'english foxhound dog', 'golden retriever dog',
  'great swiss moutain dog', 'irish water spaniel dog', 'kerry blue terrier dog', 'miniature schnazer dog', 'poodle dog', 'shih tzu dog', 'tibetan terrier dog', 'weish springer spaniel dog', 'yorkshire terrier dog']
"""

# 儲存為 .yaml 檔案
with open(yaml_path, "w") as file:
    file.write(yaml_content)

print(f"YAML 檔案已儲存到: {yaml_path}")
# Out:
# YAML 檔案已儲存到: /content/drive/MyDrive/yolo_dog_breeds/dataset/data.yaml

# %%
import yaml

# 加載 .yaml 檔案
with open(yaml_path, "r") as file:
    data = yaml.safe_load(file)

# 打印內容
print(data)
# Out:
# {'train': '/content/drive/MyDrive/yolo_dog_breeds/dataset/images/train', 'val': '/content/drive/MyDrive/yolo_dog_breeds/dataset/images/val', 'nc': 19, 'names': ["affenpinscher dog'", 'afghan hound dog', 'basenji dog', 'basset hound dog', 'cairn terrier dog', 'chihuahua dog', "dandie dinmont terrier dog'", 'deerhound dog', 'english foxhound dog', 'golden retriever dog', 'great swiss moutain dog', 'irish water spaniel dog', 'kerry blue terrier dog', 'miniature schnazer dog', 'poodle dog', 'shih tzu dog', 'tibetan terrier dog', 'weish springer spaniel dog', 'yorkshire terrier dog']}

# %%
# 加載 YOLOv8 模型 (以輕量版 yolov8n.pt 為例，可更換為 yolov8m.pt, yolov8l.pt)
model = YOLO('yolov8n.pt')

# %%
# 開始訓練
model.train(
    data="/content/drive/MyDrive/yolo_dog_breeds/dataset/data.yaml",  # YAML 文件路徑
    epochs=30,         # 訓練輪數
    batch=16,          # 批次大小
    imgsz=640,         # 圖片大小
    name="dog_breeds"  # 模型名稱
)
# Out:
# Ultralytics 8.3.55 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/content/drive/MyDrive/yolo_dog_breeds/dataset/data.yaml, epochs=30, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=dog_breeds, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/dog_breeds
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 3.12MB/s]
# Overriding model.yaml nc=80 with nc=19
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    755017  ultralytics.nn.modules.head.Detect           [19, [64, 128, 256]]
# Model summary: 225 layers, 3,014,553 parameters, 3,014,537 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/dog_breeds', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning /content/drive/MyDrive/yolo_dog_breeds/dataset/labels/train... 7732 images, 0 backgrounds, 119 corrupt: 100%|██████████| 7732/7732 [1:34:24<00:00,  1.37it/s]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n02089973_1763.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n107424.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1111]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n107425.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1856]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n107428.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1475]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n107434.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4153]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n108015.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n108362.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0354]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n110097.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n117790.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1327]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n117792.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0492]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n117793.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1841      1.3022]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n117795.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0833]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n117798.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0547       1.204]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n117803.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0139]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n117804.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2966      1.4463]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n117805.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3109]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n117807.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5146]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n117809.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2074      1.3404]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n117810.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.09]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n120002.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2879]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n120003.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1885      1.1913]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n120004.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4096]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n120005.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2879]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n120006.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5577      1.0385      1.7949]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n120008.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1263      1.2842]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n120009.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0848      1.0409]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n120010.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0882]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n121261.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n121271.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n121365.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.148]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n121366.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3112]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n121367.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.066]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n121368.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3105]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n121370.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2121]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n121371.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1515]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n121372.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2632      1.2749]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n121373.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0227]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n121375.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1232]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126287.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.119      1.2275]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126288.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4426]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126289.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2022]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126291.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.133]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126293.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.21]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126294.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.232]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126295.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0707]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126296.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0718]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126298.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3224]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126299.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1545      1.3665]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126302.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0684]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126752.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3041]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126753.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.7276      1.1891      1.5449]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126755.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.25]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126756.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2893]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126757.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1667]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126759.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6322]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126760.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3351]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126762.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5491]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126764.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.119]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126765.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0495]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126766.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0984]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126769.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2626]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126771.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.202]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126772.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0864      1.1571]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n126774.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1316]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128809.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0492]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128810.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0509]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128814.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1518      1.2679]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128815.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0328]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128820.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0685]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128821.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3885      1.0032      2.0064]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128823.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1543]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128824.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.7425]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128825.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1368]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128828.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3196]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128830.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1412]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128831.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2632]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128834.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2113]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128835.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1639]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128841.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0825]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128844.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0707      1.1685]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128845.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0137      1.4809]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128849.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3138]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128850.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2022]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128852.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.234]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128854.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1692]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128855.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2678]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128861.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0383      1.2077]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128864.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2077]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128866.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.517]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128869.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1394]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128871.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1299]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128872.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1717]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128873.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1148]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128874.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0773]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n128876.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1394]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132142.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.201]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132143.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0369      1.0057]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132145.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2938]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132148.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3443]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132149.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1707]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132151.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3005]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132153.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1639]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132154.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3956]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132156.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.204]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132164.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1913]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132168.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3037]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132169.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0856       1.123]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132172.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2459]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132174.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0149      1.0297]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132175.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0929]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132177.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0219]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132182.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2131      1.2951]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132184.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.13]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132187.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2568      1.2678]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132191.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3661]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132192.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0135]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132193.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1005]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132197.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.307      1.3509]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132199.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0409]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132201.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0419]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132203.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.075]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132207.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4205]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132208.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0109]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n132209.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2602]
# train: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/train/n146538.jpg: 1 duplicate labels removed
# train: New cache created: /content/drive/MyDrive/yolo_dog_breeds/dataset/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.24 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# val: Scanning /content/drive/MyDrive/yolo_dog_breeds/dataset/labels/val... 1933 images, 0 backgrounds, 27 corrupt: 100%|██████████| 1933/1933 [23:53<00:00,  1.35it/s]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n02089973_2054.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n107427.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1366]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n117791.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2462]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n117794.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3231]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n117796.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2326      1.2965]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n117800.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2273]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n117806.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1626]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n119999.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0192]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n120000.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0383]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n120001.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1256]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n121369.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3343      1.5843]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n121376.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1701]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n126290.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2694]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n126751.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3743]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n126768.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3333]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n128819.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0737]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n128829.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2155      1.3094]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n128832.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4551      1.1442      1.4936]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n128833.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1735]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n128840.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3511]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n132146.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4792      1.5119]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n132147.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4973]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n132178.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1268]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n132180.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4153]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n132183.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3443]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n132188.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1053]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n132189.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0047]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n132206.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5304]
# val: WARNING ⚠️ /content/drive/MyDrive/yolo_dog_breeds/dataset/images/val/n146593.jpg: 1 duplicate labels removed
# val: New cache created: /content/drive/MyDrive/yolo_dog_breeds/dataset/labels/val.cache
# Plotting labels to runs/detect/dog_breeds/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000435, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/dog_breeds
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30         0G     0.9411      3.086      1.407         48        640: 100%|██████████| 476/476 [1:46:18<00:00, 13.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 60/60 [08:28<00:00,  8.48s/it]
#                    all       1906       3223       0.36      0.409      0.354      0.251
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30         0G     0.9346      2.166      1.378         54        640:  73%|███████▎  | 347/476 [1:19:02<29:11, 13.58s/it]

# %%
# 驗證模型效能
metrics = model.val()
print(metrics)  # 包含 mAP, precision, recall 等指標

# %%
# !cp runs/detect/dog_breeds_model/weights/best.pt /content/drive/MyDrive/

# %%
import os

label_dir = "/content/drive/MyDrive/yolo_dog_breeds/dataset/labels/train"

def fix_labels(label_dir):
    for label_file in os.listdir(label_dir):
        label_path = os.path.join(label_dir, label_file)
        with open(label_path, "r") as file:
            lines = file.readlines()

        new_lines = []
        for line in lines:
            parts = line.strip().split()
            if len(parts) == 5:  # 確保是正確格式
                class_id, x_center, y_center, width, height = map(float, parts)
                # 確保座標在 0 到 1 之間
                if 0 <= x_center <= 1 and 0 <= y_center <= 1 and 0 <= width <= 1 and 0 <= height <= 1:
                    new_lines.append(line)

        # 如果有修正，覆蓋原始標註檔案
        with open(label_path, "w") as file:
            file.writelines(new_lines)

fix_labels(label_dir)
print("標註檔案已修正。")
# Out:
# 標註檔案已修正。

# %%
def check_duplicate_labels(label_dir):
    for label_file in os.listdir(label_dir):
        label_path = os.path.join(label_dir, label_file)
        with open(label_path, "r") as file:
            lines = file.readlines()
            if len(lines) != len(set(lines)):
                print(f"重複標籤檔案: {label_file}")

check_duplicate_labels(label_dir)

# %%
# 設定資料夾路徑
base_dir = "/content/drive/MyDrive/yolo_dog_breeds/dataset"
train_images_dir = os.path.join(base_dir, "images/train")
val_images_dir = os.path.join(base_dir, "images/val")
train_labels_dir = os.path.join(base_dir, "labels/train")
val_labels_dir = os.path.join(base_dir, "labels/val")

# 計算每個資料夾的檔案數量
def count_files(directory):
    if os.path.exists(directory):
        return len([f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))])
    return 0

# 計算檔案數量
num_train_images = count_files(train_images_dir)
num_val_images = count_files(val_images_dir)
num_train_labels = count_files(train_labels_dir)
num_val_labels = count_files(val_labels_dir)

# 印出結果
print(f"訓練集圖片數量: {num_train_images}")
print(f"驗證集圖片數量: {num_val_images}")
print(f"訓練集標註數量: {num_train_labels}")
print(f"驗證集標註數量: {num_val_labels}")
# Out:
# 訓練集圖片數量: 7732
# 驗證集圖片數量: 1933
# 訓練集標註數量: 7732
# 驗證集標註數量: 1933
